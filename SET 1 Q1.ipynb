# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
measures = pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
name = [ 'Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers','Marriott','MCI',
        'Merrill Lynch','Microsoft','Morgan Stanley','un Microsystems','Travelers','US Airways','Warner-Lambert']

# %%
#pie plot
plt.figure(figsize=(6,8))
plt.pie(measures,labels=name,autopct='%1.0f%%')
plt.show()

# %%
(measures.mean(),measures.var(),measures.std())
# Out:
# (33.27133333333333, 287.1466123809524, 16.945400921222028)

# %%
sns.boxplot(measures)
# Out:
# C:\Users\sneha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
boxplot to find outliers
